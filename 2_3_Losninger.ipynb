# %% [markdown]
# ## Oppgave 1 a)

# %%
aksjer = ('EQNR', 'DNB', 'STB', 'NHY', 'YAR', 'TEL', 'KOG')
print(aksjer[0])
print(aksjer[6])
print(aksjer[-1])
# Out:
# EQNR
# KOG
# KOG

# %% [markdown]
# ## Oppgave 1 b)

# %%
print(aksjer[0:4])
print(aksjer[:4])
print(aksjer[2:5])
# Out:
# ('EQNR', 'DNB', 'STB', 'NHY')
# ('EQNR', 'DNB', 'STB', 'NHY')
# ('STB', 'NHY', 'YAR')

# %% [markdown]
# ## Oppgave 2 a)

# %%
handleliste = ('Cola', 'Solo', 'Epler', 'Druer', 'Rømme', 'Kefir')
handleliste = handleliste + ('Fløte',)
print(handleliste)
# Out:
# ('Cola', 'Solo', 'Epler', 'Druer', 'Rømme', 'Kefir', 'Fløte')

# %% [markdown]
# ## Oppgave 2 b)

# %%
handleliste = list(handleliste)
handleliste.insert(4, 'Bananer')
handleliste = tuple(handleliste)
print(handleliste)
# Out:
# ('Cola', 'Solo', 'Epler', 'Druer', 'Bananer', 'Rømme', 'Kefir', 'Fløte')

# %% [markdown]
# ## Oppgave 3

# %%
pris = 32
start, stopp = '11:27', '15:03'

# Konverterer til heltall, og gjør om til timer
fra = int(start[0:2]) + int(start[3:])/60
til = int(stopp[0:2]) + int(stopp[3:])/60

# Beregner hva det koster å parkere
kostnad = (til-fra) * pris
print(f'Det koster {kostnad:.2f} kr å parkere fra {start} til {stopp}.')
# Out:
# Det koster 115.20 kr å parkere fra 11:27 til 15:03.
