# %% [markdown]
# ## Oppgave 1

# %%
# a) La bare ønsket svar være ukommentert.

2 - (4 - 6) + 8                 # i)
2 ** 3 - 4 * (5 - 6) + 7        # ii)
1 + 4 / 2 - 12 / 3              # iii)
# Out:
# 19

# %%
# b) La bare ønsket svar være ukommentert.

type(2 - (4 - 6) + 8)           # i)
type(2 ** 3 - 4 * (5 - 6) + 7)  # ii)
type(1 + 4 / 2 - 12 / 3)        # iii)

# Som standard vil alltid Python la brøker være flyttall.
# Out:
# float

# %% [markdown]
# ## Opgave 2

# %%
# a) Parentesbruk er viktig her. La bare ønsket svar stå ukommentert.

(3 ** 2 - 3 ** (1 / 2)) / ((2 / 3) - 2 ** 3)    # i)
(3 ** (1 / 4) - 2) / (2 - 4 ** (1 / 3))         # ii)
# Out:
# -1.6576047765269502

# %%
# b) Bruk at milli = 10^(-3), mikro = 10^(-6) og nano = 10^(-9)
# I Python skrives standardform med en e, for eksempel 2x10^3 = 2e3

12e-3 + 83e-6 + 1152e-9
# Out:
# 0.012084152

# %% [markdown]
# ## Oppgave 3

# %%
# Vi jobber oss nedover fra 20 kr til 1 kr:

178 // 20       # Gir 8 hele 20-kr
178 % 20        # Da er det 18 kr igjen
18 // 10        # Gir 1 hel 10-kr
18 % 10         # Da er det 8 kr igjen
8 // 5          # Gir 1 hel 5-kr
8 % 5           # Da er det 3 kr igjen
3 // 1          # Gir 3 hele 1-kr
3 % 1           # Da er det 0 kr igjen

# Fordelingen er altså 8 20-kr, 1 10-kr, 1 5-kr, 3 1-kr
# Out:
# 0
