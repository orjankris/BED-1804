# %% [markdown]
# ## Oppgave 1 a)

# %%
salg = {'Mandag': 73, 'Tirsdag': 106}
salg['Mandag']
# Out:
# 73

# %% [markdown]
# ## Oppgave 1 b)
# **Kommentar:** En ny nøkkel og dens verdi legger seg bakerst i ordboken.

# %%
salg['Onsdag'] = 92
salg
# Out:
# {'Mandag': 73, 'Tirsdag': 106, 'Onsdag': 92}

# %% [markdown]
# ## Oppgave 2 a)

# %%
bil = {'Merke': 'Subaru', 'Modell': 'Outback', 'År': 2015, 'Km': 145000}
bil['Merke']
# Out:
# 'Subaru'

# %% [markdown]
# ## Oppgave 2 b)
# **Kommentar:** Nøkkelen Km beholder sin plass i ordboken når verdien endres.

# %%
bil['Hk'] = 175
print(bil)
bil['Km'] = 153000 
print(bil)
# Out:
# {'Merke': 'Subaru', 'Modell': 'Outback', 'År': 2015, 'Km': 145000, 'Hk': 175}
# {'Merke': 'Subaru', 'Modell': 'Outback', 'År': 2015, 'Km': 153000, 'Hk': 175}

# %% [markdown]
# ## Oppgave 3 a)

# %%
frukt = {'Epler': 'Belgia', 'Bananer': 'Ecuador', 'Druer': 'Peru'}
frukt['Bananer']
# Out:
# 'Ecuador'

# %% [markdown]
# ## Oppgave 3 b)

# %%
frukt = {'Epler': {'Land': 'Belgia', 'Pris': 19.90}, 
         'Bananer': {'Land': 'Ecuador', 'Pris': 24.50},
         'Druer': {'Land': 'Peru', 'Pris': 32.50}}
print(frukt['Bananer']['Land'])
print(frukt['Druer']['Pris'])
# Out:
# Ecuador
# 32.5
