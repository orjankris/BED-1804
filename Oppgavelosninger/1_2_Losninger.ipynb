# %% [markdown]
# ## Oppgave 1 a)

# %%
inntekt = 300000
innslag_1 = 226100
sats_1 = 0.017
total_trinnskatt = (inntekt - innslag_1) * sats_1
total_trinnskatt
# Out:
# 1256.3000000000002

# %% [markdown]
# ## Oppgave 1 b)
# **Kommentar:** Programmet avsluttes med en sammenligningstest.

# %%
salgspris = 125
salgsvolum = 750
kostnader = 100000
resultat = salgspris * salgsvolum - kostnader
resultat > 0
# Out:
# False

# %% [markdown]
# ## Oppgave 2 a)
# **Kommentar:** Her følger to ulike alternativer. Begge er kanskje like naturlige å bruke.

# %%
frukt_1 = 'epler'
frukt_2 = 'pærer'
tekst_vanlig = frukt_1 + ' og ' + frukt_2 + ' på tilbud!'
tekst_stor = tekst_vanlig.upper()
tekst_stor
# Out:
# 'EPLER OG PÆRER PÅ TILBUD!'

# %%
frukt_1 = 'epler'
frukt_2 = 'pærer'
tekst = frukt_1.upper() + ' OG ' + frukt_2.upper() + ' PÅ TILBUD!'
tekst
# Out:
# 'EPLER OG PÆRER PÅ TILBUD!'

# %% [markdown]
# ## Oppgave 2 b)
# **Kommentar:** Det er selvfølgelig enklere å la isbn og aarstall være strenger i utgangspunktet, men vanligvis vil man eksternt hente inn slik informasjon som tall.

# %%
isbn = 9788245053258
aarstall = 2025
streng = 'ISBN-' + str(isbn) + '-' + str(aarstall)
streng
# Out:
# 'ISBN-9788245053258-2025'

# %% [markdown]
# ## Oppgave 3 a)

# %%
driftsinntekter = 100000
driftskostnader = 45000

resultat_for_skatt = driftsinntekter - driftskostnader
skattekostnad = 0.22 * resultat_for_skatt
resultat_etter_skatt = resultat_for_skatt - skattekostnad

resultat_for_skatt, skattekostnad, resultat_etter_skatt
# Out:
# (55000, 12100.0, 42900.0)

# %% [markdown]
# ## Oppgave 3 b)

# %%
tekst = 'Resultatet etter skatt er ' + str(resultat_etter_skatt) + ' kr'
tekst
# Out:
# 'Resultatet etter skatt er 42900.0 kr'
